# %%
import pandas as pd
import nest_asyncio
import asyncio

from inspect_ai import Epochs, Task, task, eval
from inspect_ai.dataset import MemoryDataset
from inspect_ai.agent import bridge


from paperqa2_analysis.inspect_ai_custom.sample import record_to_sample_custom, df_2_sample_bridge, UNCERTAIN_ANSWER_CHOICE
from paperqa2_analysis.inspect_ai_custom.paperqa_scorer import paperqa_scorer
from paperqa2_analysis.agents.paperqa_agent import paperqa_agent

# %%
# Import data

litqa2_test_data = pd.read_parquet("/root/paperQA2_analysis/data/LitQA_data/test-00000-of-00001.parquet")

test_dataset = df_2_sample_bridge(litqa2_test_data)

# %%
# Mini Example with 1 working sample
mini_example = {
    "question": litqa2_test_data["question"][0],
    "ideal": litqa2_test_data["ideal"][0],
    "distractors": litqa2_test_data["distractors"][0]
}

sample = record_to_sample_custom(mini_example)
mini_dataset = MemoryDataset([sample])

# %%
@task
def paperqa_eval_mini():
    return Task(
        dataset=mini_dataset,
        solver = bridge(paperqa_agent()),
        scorer=paperqa_scorer(no_answer=UNCERTAIN_ANSWER_CHOICE),
        epochs=Epochs(1, "mode")
    )
    
# asyncio.run(eval(paperqa_eval_mini()))
nest_asyncio.apply()
result = await eval(paperqa_eval_mini())
# Out:
# Output()
# user (to structured_agent):
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Please could you parse the following text and return the desired output.
#
# Text:
# Question: Approximately what percentage of topologically associated domains in the GM12878 blood cell line does
# DiffDomain classify as reorganized in the K562 cell line?
# A) 21%
# B) 51%
# C) 31%
# D) 11%
# E) 41%
# NA) Insufficient information to answer the question.
#
# Target: C
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# --------------------------------------------------------------------------------
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# >>>>>>>> USING AUTO REPLY...[0m
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/formatters.py:282  │
# │ in catch_format_error                                                                                          │
# │                                                                                                                │
# │    279 def catch_format_error(method, self, *args, **kwargs):                                                  │
# │    280 │   """show traceback on failed format call"""                                                          │
# │    281 │   try:                                                                                                │
# │ >  282 │   │   r = method(self, *args, **kwargs)                                                               │
# │    283 │   except NotImplementedError:                                                                         │
# │    284 │   │   # don't warn on NotImplementedErrors                                                            │
# │    285 │   │   return self._check_return(None, args[0])                                                        │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/formatters.py:975  │
# │ in __call__                                                                                                    │
# │                                                                                                                │
# │    972 │   │   if self.enabled:                                                                                │
# │    973 │   │   │   # lookup registered printer                                                                 │
# │    974 │   │   │   try:                                                                                        │
# │ >  975 │   │   │   │   printer = self.lookup(obj)                                                              │
# │    976 │   │   │   except KeyError:                                                                            │
# │    977 │   │   │   │   pass                                                                                    │
# │    978 │   │   │   else:                                                                                       │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/formatters.py:456  │
# │ in lookup                                                                                                      │
# │                                                                                                                │
# │    453 │   │   if obj_id in self.singleton_printers:                                                           │
# │    454 │   │   │   return self.singleton_printers[obj_id]                                                      │
# │    455 │   │   # then lookup by type                                                                           │
# │ >  456 │   │   return self.lookup_by_type(_get_type(obj))                                                      │
# │    457 │                                                                                                       │
# │    458 │   def lookup_by_type(self, typ):                                                                      │
# │    459 │   │   """Look up the registered formatter for a type.                                                 │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/formatters.py:486  │
# │ in lookup_by_type                                                                                              │
# │                                                                                                                │
# │    483 │   │   │   │   return self.deferred_printers[typ_key]                                                  │
# │    484 │   │   else:                                                                                           │
# │    485 │   │   │   for cls in pretty._get_mro(typ):                                                            │
# │ >  486 │   │   │   │   if cls in self.type_printers or self._in_deferred_types(cls):                           │
# │    487 │   │   │   │   │   return self.type_printers[cls]                                                      │
# │    488 │   │                                                                                                   │
# │    489 │   │   # If we have reached here, the lookup failed.                                                   │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/formatters.py:623  │
# │ in _in_deferred_types                                                                                          │
# │                                                                                                                │
# │    620 │   │   mod = getattr(cls, '__module__', None)                                                          │
# │    621 │   │   name = getattr(cls, '__name__', None)                                                           │
# │    622 │   │   key = (mod, name)                                                                               │
# │ >  623 │   │   if key in self.deferred_printers:                                                               │
# │    624 │   │   │   # Move the printer over to the regular registry.                                            │
# │    625 │   │   │   printer = self.deferred_printers.pop(key)                                                   │
# │    626 │   │   │   self.type_printers[cls] = printer                                                           │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/traitlets/traitlets.py:687 in   │
# │ __get__                                                                                                        │
# │                                                                                                                │
# │    684 │   │   if obj is None:                                                                                 │
# │    685 │   │   │   return self                                                                                 │
# │    686 │   │   else:                                                                                           │
# │ >  687 │   │   │   return t.cast(G, self.get(obj, cls))  # the G should encode the Optional                    │
# │    688 │                                                                                                       │
# │    689 │   def set(self, obj: HasTraits, value: S) -> None:                                                    │
# │    690 │   │   new_value = self._validate(obj, value)                                                          │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/traitlets/traitlets.py:666 in   │
# │ get                                                                                                            │
# │                                                                                                                │
# │    663 │   │   │   # This should never be reached.                                                             │
# │    664 │   │   │   raise TraitError("Unexpected error in TraitType: default value not set prope                │
# │    665 │   │   else:                                                                                           │
# │ >  666 │   │   │   return t.cast(G, value)                                                                     │
# │    667 │                                                                                                       │
# │    668 │   @t.overload                                                                                         │
# │    669 │   def __get__(self, obj: None, cls: type[t.Any]) -> Self:                                             │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/interactiveshell.p │
# │ y:2170 in showtraceback                                                                                        │
# │                                                                                                                │
# │   2167 │   │   │   │   │   │   │   if hasattr(value, "_render_traceback_"):                                    │
# │   2168 │   │   │   │   │   │   │   │   stb = value._render_traceback_()                                        │
# │   2169 │   │   │   │   │   │   │   else:                                                                       │
# │ > 2170 │   │   │   │   │   │   │   │   stb = self.InteractiveTB.structured_traceback(                          │
# │   2171 │   │   │   │   │   │   │   │   │   etype, value, tb, tb_offset=tb_offset                               │
# │   2172 │   │   │   │   │   │   │   │   )                                                                       │
# │   2173                                                                                                         │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/ultratb.py:1457 in │
# │ structured_traceback                                                                                           │
# │                                                                                                                │
# │   1454 │   │   │   self.tb = etb[0]                                                                            │
# │   1455 │   │   else:                                                                                           │
# │   1456 │   │   │   self.tb = etb                                                                               │
# │ > 1457 │   │   return FormattedTB.structured_traceback(                                                        │
# │   1458 │   │   │   self, etype, evalue, etb, tb_offset, number_of_lines_of_context                             │
# │   1459 │   │   )                                                                                               │
# │   1460                                                                                                         │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/ultratb.py:1348 in │
# │ structured_traceback                                                                                           │
# │                                                                                                                │
# │   1345 │   │   mode = self.mode                                                                                │
# │   1346 │   │   if mode in self.verbose_modes:                                                                  │
# │   1347 │   │   │   # Verbose modes need a full traceback                                                       │
# │ > 1348 │   │   │   return VerboseTB.structured_traceback(                                                      │
# │   1349 │   │   │   │   self, etype, value, tb, tb_offset, number_of_lines_of_context                           │
# │   1350 │   │   │   )                                                                                           │
# │   1351 │   │   elif mode == 'Minimal':                                                                         │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/ultratb.py:1195 in │
# │ structured_traceback                                                                                           │
# │                                                                                                                │
# │   1192 │   │   number_of_lines_of_context: int = 5,                                                            │
# │   1193 │   ):                                                                                                  │
# │   1194 │   │   """Return a nice text document describing the traceback."""                                     │
# │ > 1195 │   │   formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, numbe                │
# │   1196 │   │   │   │   │   │   │   │   │   │   │   │   │   │   │      tb_offset)                               │
# │   1197 │   │                                                                                                   │
# │   1198 │   │   colors = self.Colors  # just a shorthand + quicker name lookup                                  │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/ultratb.py:1083 in │
# │ format_exception_as_a_whole                                                                                    │
# │                                                                                                                │
# │   1080 │   │                                                                                                   │
# │   1081 │   │   tb_offset = self.tb_offset if tb_offset is None else tb_offset                                  │
# │   1082 │   │   assert isinstance(tb_offset, int)                                                               │
# │ > 1083 │   │   head = self.prepare_header(str(etype), self.long_header)                                        │
# │   1084 │   │   records = (                                                                                     │
# │   1085 │   │   │   self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []                 │
# │   1086 │   │   )                                                                                               │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/ultratb.py:999 in  │
# │ prepare_header                                                                                                 │
# │                                                                                                                │
# │    996 │                                                                                                       │
# │    997 │   def prepare_header(self, etype: str, long_version: bool = False):                                   │
# │    998 │   │   colors = self.Colors  # just a shorthand + quicker name lookup                                  │
# │ >  999 │   │   colorsnormal = colors.Normal  # used a lot                                                      │
# │   1000 │   │   exc = '%s%s%s' % (colors.excName, etype, colorsnormal)                                          │
# │   1001 │   │   width = min(75, get_terminal_size()[0])                                                         │
# │   1002 │   │   if long_version:                                                                                │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/file_proxy.py:44 in write                          │
# │                                                                                                                │
# │   41 │   │   if lines:                                                                                         │
# │   42 │   │   │   console = self.__console                                                                      │
# │   43 │   │   │   with console:                                                                                 │
# │ > 44 │   │   │   │   output = Text("\n").join(                                                                 │
# │   45 │   │   │   │   │   self.__ansi_decoder.decode_line(line) for line in lines                               │
# │   46 │   │   │   │   )                                                                                         │
# │   47 │   │   │   │   console.print(output)                                                                     │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/text.py:806 in join                                │
# │                                                                                                                │
# │    803 │   │   offset = 0                                                                                      │
# │    804 │   │   _Span = Span                                                                                    │
# │    805 │   │                                                                                                   │
# │ >  806 │   │   for text in iter_text():                                                                        │
# │    807 │   │   │   extend_text(text._text)                                                                     │
# │    808 │   │   │   if text.style:                                                                              │
# │    809 │   │   │   │   append_span(_Span(offset, offset + len(text), text.style))                              │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/text.py:793 in iter_text                           │
# │                                                                                                                │
# │    790 │   │                                                                                                   │
# │    791 │   │   def iter_text() -> Iterable["Text"]:                                                            │
# │    792 │   │   │   if self.plain:                                                                              │
# │ >  793 │   │   │   │   for last, line in loop_last(lines):                                                     │
# │    794 │   │   │   │   │   yield line                                                                          │
# │    795 │   │   │   │   │   if not last:                                                                        │
# │    796 │   │   │   │   │   │   yield self                                                                      │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/_loop.py:22 in loop_last                           │
# │                                                                                                                │
# │   19 │   """Iterate and generate a tuple with a flag for last value."""                                        │
# │   20 │   iter_values = iter(values)                                                                            │
# │   21 │   try:                                                                                                  │
# │ > 22 │   │   previous_value = next(iter_values)                                                                │
# │   23 │   except StopIteration:                                                                                 │
# │   24 │   │   return                                                                                            │
# │   25 │   for value in iter_values:                                                                             │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/file_proxy.py:45 in <genexpr>                      │
# │                                                                                                                │
# │   42 │   │   │   console = self.__console                                                                      │
# │   43 │   │   │   with console:                                                                                 │
# │   44 │   │   │   │   output = Text("\n").join(                                                                 │
# │ > 45 │   │   │   │   │   self.__ansi_decoder.decode_line(line) for line in lines                               │
# │   46 │   │   │   │   )                                                                                         │
# │   47 │   │   │   │   console.print(output)                                                                     │
# │   48 │   │   return len(text)                                                                                  │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# ┌────────────────────────────────────── Traceback (most recent call last) ───────────────────────────────────────┐
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/inspect_ai/_eval/task/run.py:678 in task_run_sample     │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/inspect_ai/solver/_plan.py:106 in __call__              │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/inspect_ai/agent/_as_solver.py:66 in solve              │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/inspect_ai/agent/_bridge/bridge.py:69 in execute        │
# │                                                                                                                │
# │ /root/paperQA2_analysis/paperqa2_analysis/agents/paperqa_agent.py:26 in run                                    │
# │                                                                                                                │
# │    23 │   │                                                                                                    │
# │    24 │   │   # Get the input message and decode into output                                                   │
# │    25 │   │   # Use the strucuted agent                                                                        │
# │ >  26 │   │   input_str = structured_agent(sample["messages"][0]["content"], StructuredInput)                  │
# │    27 │   │   message = json.loads(input_str)                                                                  │
# │    28 │   │   question = message["question"]                                                                   │
# │    29 │   │   target = message["target"]                                                                       │
# │                                                                                                                │
# │ /root/paperQA2_analysis/paperqa2_analysis/agents/structured_agent.py:68 in structured_agent                    │
# │                                                                                                                │
# │    65 │   │   max_turns=1,                                                                                     │
# │    66 │   )                                                                                                    │
# │    67 │                                                                                                        │
# │ >  68 │   response.process()                                                                                   │
# │    69 │                                                                                                        │
# │    70 │   # Get the final message                                                                              │
# │    71 │   final_message = response.messages[-1]                                                                │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/autogen/io/run_response.py:199 in process               │
# │                                                                                                                │
# │   196 │                                                                                                        │
# │   197 │   def process(self, processor: Optional[EventProcessorProtocol] = None) -> None:                       │
# │   198 │   │   processor = processor or ConsoleEventProcessor()                                                 │
# │ > 199 │   │   processor.process(self)                                                                          │
# │   200 │                                                                                                        │
# │   201 │   def set_ui_tools(self, tools: list[Tool]) -> None:                                                   │
# │   202 │   │   """Set the UI tools for the agents."""                                                           │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/autogen/io/processors/console_event_processor.py:20 in  │
# │ process                                                                                                        │
# │                                                                                                                │
# │   17 class ConsoleEventProcessor:                                                                              │
# │   18 │   def process(self, response: "RunResponseProtocol") -> None:                                           │
# │   19 │   │   for event in response.events:                                                                     │
# │ > 20 │   │   │   self.process_event(event)                                                                     │
# │   21 │                                                                                                         │
# │   22 │   def process_event(self, event: BaseEvent) -> None:                                                    │
# │   23 │   │   if isinstance(event, InputRequestEvent):                                                          │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/autogen/io/processors/console_event_processor.py:30 in  │
# │ process_event                                                                                                  │
# │                                                                                                                │
# │   27 │   │   │   result = input(prompt)                                                                        │
# │   28 │   │   │   event.content.respond(result)  # type: ignore[attr-defined]                                   │
# │   29 │   │   else:                                                                                             │
# │ > 30 │   │   │   event.print()                                                                                 │
# │   31                                                                                                           │
# │   32                                                                                                           │
# │   33 @export_module("autogen.io")                                                                              │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/autogen/events/base_event.py:74 in print                │
# │                                                                                                                │
# │    71 │   │   │   │   │   super().__init__(content=event_cls(*args, **data), **data)                           │
# │    72 │   │                                                                                                    │
# │    73 │   │   def print(self, f: Optional[Callable[..., Any]] = None) -> None:                                 │
# │ >  74 │   │   │   self.content.print(f)  # type: ignore[attr-defined]                                          │
# │    75 │                                                                                                        │
# │    76 │   wrapper_cls = create_model(event_cls.__name__, __base__=WrapperBase)                                 │
# │    77                                                                                                          │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/autogen/events/agent_events.py:664 in print             │
# │                                                                                                                │
# │    661 │   def print(self, f: Optional[Callable[..., Any]] = None) -> None:                                    │
# │    662 │   │   f = f or print                                                                                  │
# │    663 │   │                                                                                                   │
# │ >  664 │   │   f(colored("\n>>>>>>>> USING AUTO REPLY...", "red"), flush=True)                                 │
# │    665                                                                                                         │
# │    666                                                                                                         │
# │    667 @wrap_event                                                                                             │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/file_proxy.py:43 in write                          │
# │                                                                                                                │
# │   40 │   │   │   │   break                                                                                     │
# │   41 │   │   if lines:                                                                                         │
# │   42 │   │   │   console = self.__console                                                                      │
# │ > 43 │   │   │   with console:                                                                                 │
# │   44 │   │   │   │   output = Text("\n").join(                                                                 │
# │   45 │   │   │   │   │   self.__ansi_decoder.decode_line(line) for line in lines                               │
# │   46 │   │   │   │   )                                                                                         │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:864 in __exit__                         │
# │                                                                                                                │
# │    861 │                                                                                                       │
# │    862 │   def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:                          │
# │    863 │   │   """Exit buffer context."""                                                                      │
# │ >  864 │   │   self._exit_buffer()                                                                             │
# │    865 │                                                                                                       │
# │    866 │   def begin_capture(self) -> None:                                                                    │
# │    867 │   │   """Begin capturing console output. Call :meth:`end_capture` to exit capture mode                │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:822 in _exit_buffer                     │
# │                                                                                                                │
# │    819 │   def _exit_buffer(self) -> None:                                                                     │
# │    820 │   │   """Leave buffer context, and render content if required."""                                     │
# │    821 │   │   self._buffer_index -= 1                                                                         │
# │ >  822 │   │   self._check_buffer()                                                                            │
# │    823 │                                                                                                       │
# │    824 │   def set_live(self, live: "Live") -> None:                                                           │
# │    825 │   │   """Set Live instance. Used by Live context manager.                                             │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:2019 in _check_buffer                   │
# │                                                                                                                │
# │   2016 │   │   │   return                                                                                      │
# │   2017 │   │                                                                                                   │
# │   2018 │   │   try:                                                                                            │
# │ > 2019 │   │   │   self._write_buffer()                                                                        │
# │   2020 │   │   except BrokenPipeError:                                                                         │
# │   2021 │   │   │   self.on_broken_pipe()                                                                       │
# │   2022                                                                                                         │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:2035 in _write_buffer                   │
# │                                                                                                                │
# │   2032 │   │   │   │   if self.is_jupyter:  # pragma: no cover                                                 │
# │   2033 │   │   │   │   │   from .jupyter import display                                                        │
# │   2034 │   │   │   │   │                                                                                       │
# │ > 2035 │   │   │   │   │   display(self._buffer, self._render_buffer(self._buffer[:]))                         │
# │   2036 │   │   │   │   │   del self._buffer[:]                                                                 │
# │   2037 │   │   │   │   else:                                                                                   │
# │   2038 │   │   │   │   │   if WINDOWS:                                                                         │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/jupyter.py:91 in display                           │
# │                                                                                                                │
# │    88 │   try:                                                                                                 │
# │    89 │   │   from IPython.display import display as ipython_display                                           │
# ...
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:2019 in _check_buffer                   │
# │                                                                                                                │
# │   2016 │   │   │   return                                                                                      │
# │   2017 │   │                                                                                                   │
# │   2018 │   │   try:                                                                                            │
# │ > 2019 │   │   │   self._write_buffer()                                                                        │
# │   2020 │   │   except BrokenPipeError:                                                                         │
# │   2021 │   │   │   self.on_broken_pipe()                                                                       │
# │   2022                                                                                                         │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:2035 in _write_buffer                   │
# │                                                                                                                │
# │   2032 │   │   │   │   if self.is_jupyter:  # pragma: no cover                                                 │
# │   2033 │   │   │   │   │   from .jupyter import display                                                        │
# │   2034 │   │   │   │   │                                                                                       │
# │ > 2035 │   │   │   │   │   display(self._buffer, self._render_buffer(self._buffer[:]))                         │
# │   2036 │   │   │   │   │   del self._buffer[:]                                                                 │
# │   2037 │   │   │   │   else:                                                                                   │
# │   2038 │   │   │   │   │   if WINDOWS:                                                                         │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/jupyter.py:91 in display                           │
# │                                                                                                                │
# │    88 │   try:                                                                                                 │
# │    89 │   │   from IPython.display import display as ipython_display                                           │
# │    90 │   │                                                                                                    │
# │ >  91 │   │   ipython_display(jupyter_renderable)                                                              │
# │    92 │   except ModuleNotFoundError:                                                                          │
# │    93 │   │   # Handle the case where the Console has force_jupyter=True,                                      │
# │    94 │   │   # but IPython is not installed.                                                                  │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/display_functions. │
# │ py:298 in display                                                                                              │
# │                                                                                                                │
# │   295 │   │   if raw:                                                                                          │
# │   296 │   │   │   publish_display_data(data=obj, metadata=metadata, **kwargs)                                  │
# │   297 │   │   else:                                                                                            │
# │ > 298 │   │   │   format_dict, md_dict = format(obj, include=include, exclude=exclude)                         │
# │   299 │   │   │   if not format_dict:                                                                          │
# │   300 │   │   │   │   # nothing to display (e.g. _ipython_display_ took over)                                  │
# │   301 │   │   │   │   continue                                                                                 │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/formatters.py:204  │
# │ in format                                                                                                      │
# │                                                                                                                │
# │    201 │   │   format_dict = {}                                                                                │
# │    202 │   │   md_dict = {}                                                                                    │
# │    203 │   │                                                                                                   │
# │ >  204 │   │   if self.ipython_display_formatter(obj):                                                         │
# │    205 │   │   │   # object handled itself, don't proceed                                                      │
# │    206 │   │   │   return {}, {}                                                                               │
# │    207                                                                                                         │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/decorator.py:232 in fun         │
# │                                                                                                                │
# │   229 │   │   def fun(*args, **kw):                                                                            │
# │   230 │   │   │   if not kwsyntax:                                                                             │
# │   231 │   │   │   │   args, kw = fix(args, kw, sig)                                                            │
# │ > 232 │   │   │   return caller(func, *(extras + args), **kw)                                                  │
# │   233 │   fun.__name__ = func.__name__                                                                         │
# │   234 │   fun.__doc__ = func.__doc__                                                                           │
# │   235 │   fun.__wrapped__ = func                                                                               │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/formatters.py:290  │
# │ in catch_format_error                                                                                          │
# │                                                                                                                │
# │    287 │   │   exc_info = sys.exc_info()                                                                       │
# │    288 │   │   ip = get_ipython()                                                                              │
# │    289 │   │   if ip is not None:                                                                              │
# │ >  290 │   │   │   ip.showtraceback(exc_info)                                                                  │
# │    291 │   │   else:                                                                                           │
# │    292 │   │   │   traceback.print_exception(*exc_info)                                                        │
# │    293 │   │   return self._check_return(None, args[0])                                                        │
# │                                                                                                                │
# │ /root/cw_a1/pan31/casa-6.7.0-31-py3.12.el8/lib/py/lib/python3.12/site-packages/IPython/core/interactiveshell.p │
# │ y:2175 in showtraceback                                                                                        │
# │                                                                                                                │
# │   2172 │   │   │   │   │   │   │   │   )                                                                       │
# │   2173 │   │   │   │   │   │                                                                                   │
# │   2174 │   │   │   │   │   │   except Exception:                                                               │
# │ > 2175 │   │   │   │   │   │   │   print(                                                                      │
# │   2176 │   │   │   │   │   │   │   │   "Unexpected exception formatting exception. Falling back                │
# │   2177 │   │   │   │   │   │   │   )                                                                           │
# │   2178 │   │   │   │   │   │   │   traceback.print_exc()                                                       │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/file_proxy.py:43 in write                          │
# │                                                                                                                │
# │   40 │   │   │   │   break                                                                                     │
# │   41 │   │   if lines:                                                                                         │
# │   42 │   │   │   console = self.__console                                                                      │
# │ > 43 │   │   │   with console:                                                                                 │
# │   44 │   │   │   │   output = Text("\n").join(                                                                 │
# │   45 │   │   │   │   │   self.__ansi_decoder.decode_line(line) for line in lines                               │
# │   46 │   │   │   │   )                                                                                         │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:864 in __exit__                         │
# │                                                                                                                │
# │    861 │                                                                                                       │
# │    862 │   def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:                          │
# │    863 │   │   """Exit buffer context."""                                                                      │
# │ >  864 │   │   self._exit_buffer()                                                                             │
# │    865 │                                                                                                       │
# │    866 │   def begin_capture(self) -> None:                                                                    │
# │    867 │   │   """Begin capturing console output. Call :meth:`end_capture` to exit capture mode                │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:822 in _exit_buffer                     │
# │                                                                                                                │
# │    819 │   def _exit_buffer(self) -> None:                                                                     │
# │    820 │   │   """Leave buffer context, and render content if required."""                                     │
# │    821 │   │   self._buffer_index -= 1                                                                         │
# │ >  822 │   │   self._check_buffer()                                                                            │
# │    823 │                                                                                                       │
# │    824 │   def set_live(self, live: "Live") -> None:                                                           │
# │    825 │   │   """Set Live instance. Used by Live context manager.                                             │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:2019 in _check_buffer                   │
# │                                                                                                                │
# │   2016 │   │   │   return                                                                                      │
# │   2017 │   │                                                                                                   │
# │   2018 │   │   try:                                                                                            │
# │ > 2019 │   │   │   self._write_buffer()                                                                        │
# │   2020 │   │   except BrokenPipeError:                                                                         │
# │   2021 │   │   │   self.on_broken_pipe()                                                                       │
# │   2022                                                                                                         │
# │                                                                                                                │
# │ /root/venvs/venv_paperQA2/lib/python3.12/site-packages/rich/console.py:2031 in _write_buffer                   │
# │                                                                                                                │
# │   2028 │   │   │   │   with self._record_buffer_lock:                                                          │
# │   2029 │   │   │   │   │   self._record_buffer.extend(self._buffer[:])                                         │
# │   2030 │   │   │                                                                                               │
# │ > 2031 │   │   │   if self._buffer_index == 0:                                                                 │
# │   2032 │   │   │   │   if self.is_jupyter:  # pragma: no cover                                                 │
# │   2033 │   │   │   │   │   from .jupyter import display                                                        │
# │   2034                                                                                                         │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# RecursionError: maximum recursion depth exceeded
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 12
#      10 # asyncio.run(eval(paperqa_eval_mini()))
#      11 nest_asyncio.apply()
# ---> 12 result = await eval(paperqa_eval_mini())
#
# TypeError: object EvalLogs can't be used in 'await' expression
